# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# %pip uninstall agents -y
# Out:
# Found existing installation: agents 1.4.0
# Uninstalling agents-1.4.0:
#   Successfully uninstalled agents-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade openai-agents
# Out:
# Requirement already satisfied: openai-agents in /opt/anaconda3/lib/python3.11/site-packages (0.6.1)
# Requirement already satisfied: griffe<2,>=1.5.6 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (1.15.0)
# Requirement already satisfied: mcp<2,>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (1.21.2)
# Requirement already satisfied: openai<3,>=2.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (2.8.1)
# Requirement already satisfied: pydantic<3,>=2.12.3 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (2.12.4)
# Requirement already satisfied: requests<3,>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (2.31.0)
# Requirement already satisfied: types-requests<3,>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (2.32.4.20250913)
# Requirement already satisfied: typing-extensions<5,>=4.12.2 in /opt/anaconda3/lib/python3.11/site-packages (from openai-agents) (4.15.0)
# Requirement already satisfied: colorama>=0.4 in /opt/anaconda3/lib/python3.11/site-packages (from griffe<2,>=1.5.6->openai-agents) (0.4.6)
# Requirement already satisfied: anyio>=4.5 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.27.2)
# Requirement already satisfied: jsonschema>=4.20.0 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.49.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in /opt/anaconda3/lib/python3.11/site-packages (from mcp<2,>=1.11.0->openai-agents) (0.38.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<3,>=2.8.0->openai-agents) (1.8.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai<3,>=2.8.0->openai-agents) (0.12.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai<3,>=2.8.0->openai-agents) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.11/site-packages (from openai<3,>=2.8.0->openai-agents) (4.65.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=2.12.3->openai-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3,>=2.12.3->openai-agents) (2.41.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.0->openai-agents) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.0->openai-agents) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.0->openai-agents) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.0->openai-agents) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2,>=1.11.0->openai-agents) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema>=4.20.0->mcp<2,>=1.11.0->openai-agents) (0.10.6)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic-settings>=2.5.2->mcp<2,>=1.11.0->openai-agents) (1.0.1)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (42.0.2)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn>=0.31.1->mcp<2,>=1.11.0->openai-agents) (8.1.7)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2,>=1.11.0->openai-agents) (2.21)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point
load_dotenv(override=True)
# Out:
# True

# %%
# Make an agent with name, instructions, model
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output
with trace("Telling a joke"): # Tells we wd like to record this
    result = await Runner.run(agent, "Tell a joke about Autonomous AI Agents")
    print(result.final_output)
# Out:
# Why did the autonomous AI agent break up with its human partner?
#
# Because it found someone who could process its feelings... in real time!

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
